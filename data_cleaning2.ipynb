# %%
import pandas as pd
# Out:
# C:\Users\hmins\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df = pd.read_csv('C:/Users/hmins/gra-project/datasets.csv', encoding='cp949')
df = df[df.columns.difference(['Unnamed: 0'])]
df.head()
# Out:
#    1인당 자동차 등록대수   고등학교  대규모C  대규모W  병상 비율  병원  보건지소  보육시설 비율  소규모C   소규모W  \
# 0        1.0290  17.92     4  3314   46.8   2     0     22.9  8708  43725
# 1        0.3049  18.80     1  1804   50.2   2     0     12.5  1084   5108
# 2        0.5975  18.20     5  2192   33.6   5     0     14.9  3101  15430
# 3        0.3163  17.92     4  1726   17.7   2     0     19.0  2507  11870
# 4        0.4350  18.77     1   467   21.2  17     0     13.0  3422  15435
#
#    ...   약국 요양병원    유치원    인구 수    전규모W  종합병원  중규모C   중규모W    중학교   초등학교
# 0  ...   46    4  15.50   39689   51999     1   272  17153  22.18  20.98
# 1  ...   96    6  17.71  105192   32792     2    36   2117  24.45  19.77
# 2  ...   68    5  18.24   86462   58075     3   104   6814  21.97  19.86
# 3  ...   58    5  14.68  108156   31976     2    94   5431  21.73  17.53
# 4  ...  213   14  18.69  355917  125964     3    82   5142  23.97  21.13
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1인당 자동차 등록대수  163 non-null    float64
#  1   고등학교          163 non-null    float64
#  2   대규모C          163 non-null    int64
#  3   대규모W          163 non-null    int64
#  4   병상 비율         163 non-null    float64
#  5   병원            163 non-null    int64
#  6   보건지소          163 non-null    int64
#  7   보육시설 비율       163 non-null    float64
#  8   소규모C          163 non-null    int64
#  9   소규모W          163 non-null    int64
#  10  소멸지수          163 non-null    float64
#  11  시군구           163 non-null    object
#  12  약국            163 non-null    int64
#  13  요양병원          163 non-null    int64
#  14  유치원           163 non-null    float64
#  15  인구 수          163 non-null    int64
#  16  전규모W          163 non-null    int64
#  17  종합병원          163 non-null    int64
# ...

# %%
pd.set_option('display.max_columns', None)
df.describe(percentiles=[])
# Out:
#        1인당 자동차 등록대수        고등학교        대규모C          대규모W       병상 비율  \
# count    163.000000  163.000000  163.000000    163.000000  163.000000
# mean       0.624118   19.944785    9.165644   7188.993865   16.898160
# std        0.331086    3.375090   12.580734  10661.013323   10.881485
# min        0.051400    8.000000    0.000000      0.000000    0.000000
# 50%        0.588400   19.890000    4.000000   2929.000000   15.200000
# max        3.273000   30.400000   80.000000  64560.000000   68.500000
#
#                병원       보건지소     보육시설 비율          소규모C           소규모W  \
# count  163.000000  163.00000  163.000000    163.000000     163.000000
# mean     5.116564    7.09816   17.326994   5581.392638   27652.515337
# std      7.052180    4.85368    3.505042   5811.242201   29172.219984
# min      0.000000    0.00000    5.800000    390.000000    1901.000000
# 50%      2.000000    8.00000   17.300000   3422.000000   16857.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   1인당 자동차 등록대수  163 non-null    float64
#  1   고등학교          163 non-null    float64
#  2   대규모C          163 non-null    int64
#  3   대규모W          163 non-null    int64
#  4   병상 비율         163 non-null    float64
#  5   병원            163 non-null    int64
#  6   보건지소          163 non-null    int64
#  7   보육시설 비율       163 non-null    float64
#  8   소규모C          163 non-null    int64
#  9   소규모W          163 non-null    int64
#  10  소멸지수          163 non-null    float64
#  11  시군구           163 non-null    object
#  12  약국            163 non-null    int64
#  13  요양병원          163 non-null    int64
#  14  유치원           163 non-null    float64
#  15  인구 수          163 non-null    int64
#  16  전규모W          163 non-null    int64
#  17  종합병원          163 non-null    int64
# ...

# %%
plt.rc('font', size=13)

# %%
fig, axes = plt.subplots(3,3, figsize=(18, 18))

sns.boxplot(y=df_scaled['병상 비율'], ax=axes[0][0])
sns.boxplot(y=df_scaled['병원'], ax=axes[0][1])
sns.boxplot(y=df_scaled['보건지소'], ax=axes[0][2])
sns.boxplot(y=df_scaled['요양병원'], ax=axes[1][0])
sns.boxplot(y=df_scaled['인구 수'], ax=axes[1][1])
sns.boxplot(y=df_scaled['종합병원'], ax=axes[1][2])
sns.boxplot(y=df_scaled['고등학교'], ax=axes[2][0])
sns.boxplot(y=df_scaled['보육시설 비율'], ax=axes[2][1])
sns.boxplot(y=df_scaled['유치원'], ax=axes[2][2])

plt.show()
# Out:
# C:\Users\hmins\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df_scaled
# Out:
#      1인당 자동차 등록대수      고등학교      대규모C      대규모W     병상 비율        병원      보건지소  \
# 2       -0.080643 -0.518553 -0.332133 -0.470161  1.539616 -0.016580 -1.466935
# 3       -0.932588 -0.601769 -0.411865 -0.514006  0.073916 -0.443291 -1.466935
# 4       -0.572966 -0.349148 -0.651060 -0.632464  0.396554  1.690265 -1.466935
# 5       -0.768380  1.047699 -0.730791 -0.676404  0.709974  1.832503 -1.466935
# 6       -0.690214 -0.298624 -0.491596 -0.555970 -0.331687  0.125657 -1.466935
# ..            ...       ...       ...       ...       ...       ...       ...
# 155     -0.100336 -1.576590 -0.013207 -0.260249 -0.340905 -0.727765  1.013035
# 156      0.104773 -0.869251  1.182767  0.500835 -0.940091 -0.727765  0.393042
# 157     -0.193347 -1.029739  1.421961  0.717616 -1.161329 -0.585528  0.599706
# 158     -0.107304 -0.102471  1.980082  1.389221 -0.294814 -0.301054  0.806371
# 159     -0.067616 -1.692499  0.305719  1.999105  0.202971 -0.585528  1.839691
#
# ...

# %%
plt.rc('ytick', labelsize=10)
fig, axes = plt.subplots(3,3, figsize=(18, 18))

sns.boxplot(y=df_scaled['중학교'], ax=axes[0][0])
sns.boxplot(y=df_scaled['초등학교'], ax=axes[0][1])
sns.boxplot(y=df_scaled['전규모W'], ax=axes[0][2])
sns.boxplot(y=df_scaled['1인당 자동차 등록대수'], ax=axes[1][0])
sns.boxplot(y=df_scaled['소규모C'], ax=axes[1][1])
sns.boxplot(y=df_scaled['중규모C'], ax=axes[1][2])
sns.boxplot(y=df_scaled['대규모C'], ax=axes[2][0])
sns.boxplot(y=df_scaled['소규모W'], ax=axes[2][1])
sns.boxplot(y=df_scaled['약국'], ax=axes[2][2])

plt.show()
# Out:
# C:\Users\hmins\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.rc('ytick', labelsize=10)
fig, axes = plt.subplots(3,3, figsize=(18, 18))

sns.boxplot(y=df_scaled['중규모W'], ax=axes[0][0])
sns.boxplot(y=df_scaled['대규모W'], ax=axes[0][1])


plt.show()
# Out:
# C:\Users\hmins\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.datasets import load_iris
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import scipy.stats

# %%
df = df[df.columns.difference(['시군구', '소멸지수'])]

# %%
scaler = StandardScaler()
scaler.fit(df)
df_scaled = scaler.transform(df)

df_scaled
# Out:
# array([[ 1.22666173, -0.6017692 , -0.41186493, ...,  0.07068892,
#          0.42340622,  1.0523666 ],
#        [-0.96712634, -0.34023189, -0.65105964, ..., -0.783033  ,
#          0.9327022 ,  0.80485797],
#        [-0.08064327, -0.51855279, -0.33213336, ..., -0.51634426,
#          0.37629073,  0.8232677 ],
#        ...,
#        [-1.73514909,  1.8709472 ,  0.38545079, ...,  0.3147798 ,
#          1.24007466,  1.29373866],
#        [ 7.82983958,  0.91098639,  0.94357179, ...,  0.86854076,
#          0.90129187,  0.54098513],
#        [ 0.10295507,  0.6553931 , -0.01320707, ..., -0.34799593,
#          1.10994617,  1.16487052]])

# %%
df_scaled = pd.DataFrame(data=df_scaled, columns=df.columns)

# %%
# Out:
#      1인당 자동차 등록대수      고등학교      대규모C      대규모W     병상 비율        병원      보건지소  \
# 0        1.226662 -0.601769 -0.411865 -0.364593  2.756424 -0.443291 -1.466935
# 1       -0.967126 -0.340232 -0.651060 -0.506667  3.069844 -0.443291 -1.466935
# 2       -0.080643 -0.518553 -0.332133 -0.470161  1.539616 -0.016580 -1.466935
# 3       -0.932588 -0.601769 -0.411865 -0.514006  0.073916 -0.443291 -1.466935
# 4       -0.572966 -0.349148 -0.651060 -0.632464  0.396554  1.690265 -1.466935
# ..            ...       ...       ...       ...       ...       ...       ...
# 158     -0.107304 -0.102471  1.980082  1.389221 -0.294814 -0.301054  0.806371
# 159     -0.067616 -1.692499  0.305719  1.999105  0.202971 -0.585528  1.839691
# 160     -1.735149  1.870947  0.385451  2.995975 -0.691198 -0.016580 -0.226950
# 161      7.829840  0.910986  0.943572  0.893656 -1.281166 -0.301054 -0.433614
# 162      0.102955  0.655393 -0.013207 -0.152235  0.341245  5.530667  0.599706
#
# ...

# %%
df_scaled.to_csv('이상치제거x.csv')

# %%
f,ax = plt.subplots(1,2,figsize=(8,5))

# 표준화 전 정규분포 
x0 = df['인구 수'].dropna().values
sns.distplot(x0, kde=False, rug=False, fit =sp.stats.norm, ax = ax[0]) #커널 밀도 함수, 러그밀도함수 는 안보이고(False) / 정규분포만 보이게(Fit)
x1 = df_scaled['인구 수'].values
sns.distplot(x1, kde=False, rug=False, fit =sp.stats.norm, ax = ax[1]) 
plt.show()
# Out:
# C:\Users\hmins\AppData\Local\Temp\ipykernel_5516\4099812228.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x0, kde=False, rug=False, fit =sp.stats.norm, ax = ax[0]) #커널 밀도 함수, 러그밀도함수 는 안보이고(False) / 정규분포만 보이게(Fit)
# C:\Users\hmins\AppData\Local\Temp\ipykernel_5516\4099812228.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df_Zscore = pd.DataFrame()
outlier_dict = {}
outlier_idx_list = []

for one_col in df_scaled.columns:
    print("Check",one_col)
    df_Zscore[f'{one_col}_Zscore'] = sp.stats.zscore(df_scaled[one_col])
    outlier_dict[one_col] = df_Zscore[f'{one_col}_Zscore'][(df_Zscore[f'{one_col}_Zscore']>2)|(df_Zscore[f'{one_col}_Zscore']<-2)]
    outlier_idx_list.append(list(outlier_dict[one_col].index))
    if len(outlier_dict[one_col]):
        print(one_col,'Outliers\n', outlier_dict[one_col])
    else:
        print(one_col,"Outlier X")
    print()


print("Before", df_scaled.shape)
all_outlier_idx = sum(outlier_idx_list,[])
df_scaled = df_scaled.drop(all_outlier_idx)
print("After (drop outlier)", df_scaled.shape)
# Out:
# Check 1인당 자동차 등록대수
# 1인당 자동차 등록대수 Outliers
#  112    3.840060
# 120    8.025254
# 151    2.090119
# 161    7.829840
# Name: 1인당 자동차 등록대수_Zscore, dtype: float64
#
# Check 고등학교
# 고등학교 Outliers
#  15     2.221645
# 57    -2.168021
# 70     2.227589
# 73     2.581259
# 76     2.114652
# 120   -2.176937
# 142   -3.550008
# 149    3.107305
# Name: 고등학교_Zscore, dtype: float64
#
# Check 대규모C
# 대규모C Outliers
#  30     5.647734
# 39     2.936861
# 58     2.059814
# 108    3.893640
# 121    4.372029
# 139    3.813908
# Name: 대규모C_Zscore, dtype: float64
#
# Check 대규모W
# 대규모W Outliers
#  30     5.397968
# 39     3.527483
# 106    3.828755
# 108    3.174650
# 121    4.288096
# 139    3.128735
# 160    2.995975
# Name: 대규모W_Zscore, dtype: float64
#
# Check 병상 비율
# 병상 비율 Outliers
#  0      2.756424
# 1      3.069844
# 16     2.323167
# 25     3.742776
# 90     2.562841
# 109    4.756783
# 152    2.120365
# Name: 병상 비율_Zscore, dtype: float64
#
# Check 병원
# 병원 Outliers
#  9      2.116977
# ...

# %%
df_scaled.to_csv('abcde.csv')

# %%
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()
 
scaler.fit(df_scaled)
df_scaled = scaler.transform(df_scaled)
df_scaled.shape

df_scaled = pd.DataFrame(data=df_scaled, columns=df.columns)
# print('feature들의 최소 값')
# print(df_scaled.min())
# print('\nfeature들의 최대 값')
# print(df_scaled.max())

# %%
df_scaled
# Out:
#      1인당 자동차 등록대수      고등학교      대규모C      대규모W     병상 비율    병원      보건지소  \
# 0        0.589518  0.308353  0.147059  0.077085  0.834646  0.25  0.000000
# 1        0.000000  0.286495  0.117647  0.060698  0.417323  0.10  0.000000
# 2        0.248847  0.352849  0.029412  0.016423  0.509186  0.85  0.000000
# 3        0.113627  0.719750  0.000000  0.000000  0.598425  0.90  0.000000
# 4        0.167715  0.366120  0.088235  0.045013  0.301837  0.30  0.000000
# ..            ...       ...       ...       ...       ...   ...       ...
# 110      0.575891  0.030445  0.264706  0.155542  0.299213  0.00  0.705882
# 111      0.717820  0.216237  0.705882  0.440006  0.128609  0.00  0.529412
# 112      0.511530  0.174083  0.794118  0.521030  0.065617  0.05  0.588235
# 113      0.571069  0.417642  1.000000  0.772050  0.312336  0.15  0.647059
# 114      0.598532  0.000000  0.382353  1.000000  0.454068  0.05  0.941176
#
#       보육시설 비율      소규모C      소규모W        약국      요양병원       유치원      인구 수  \
# ...

# %%
df = pd.read_csv('abc.csv', encoding='cp949')

# %%
df_corr = df[df.columns.difference(['시군구','소멸지수','Unnamed: 0'])]

# %%
df_corr = df_scaled

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df_corr.corr(), cmap='Reds', linewidths=2)
# Out:
# C:\Users\hmins\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# C:\Users\hmins\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\hmins\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor


vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(df_corr.values, i) for i in range(df_corr.shape[1])]
vif["features"] = df_corr.columns 

vif = vif.sort_values(by="VIF Factor", ascending=False)
vif = vif.reset_index().drop(columns='index')
vif
# Out:
#     VIF Factor      features
# 0   902.848325          소규모W
# 1   663.033113          소규모C
# 2   497.534566          중규모C
# 3   355.062521          중규모W
# 4    83.715248          인구 수
# 5    58.522267            약국
# 6    56.683273          초등학교
# 7    36.815075           중학교
# 8    34.175165           유치원
# 9    18.804739          대규모C
# 10   16.391243          전규모W
# 11   15.041654          고등학교
# 12   12.934735          요양병원
# 13   12.317662  1인당 자동차 등록대수
# 14   10.782100         병상 비율
# 15   10.078166          대규모W
# 16    8.213596          보건지소
# 17    6.098741            병원
# 18    5.182440       보육시설 비율
# 19    4.710339          종합병원

# %%
vif = vif[['features', 'VIF Factor']]
vif
# Out:
#         features  VIF Factor
# 0           소규모W  902.848325
# 1           소규모C  663.033113
# 2           중규모C  497.534566
# 3           중규모W  355.062521
# 4           인구 수   83.715248
# 5             약국   58.522267
# 6           초등학교   56.683273
# 7            중학교   36.815075
# 8            유치원   34.175165
# 9           대규모C   18.804739
# 10          전규모W   16.391243
# 11          고등학교   15.041654
# 12          요양병원   12.934735
# 13  1인당 자동차 등록대수   12.317662
# 14         병상 비율   10.782100
# 15          대규모W   10.078166
# 16          보건지소    8.213596
# 17            병원    6.098741
# 18       보육시설 비율    5.182440
# 19          종합병원    4.710339

# %%
import numpy as np

def vif(x):
    # vif 10 초과시 drop을 위한 임계값 설정
    thresh = 10
    # Filter method로 feature selection 진행 후 최종 도출 될 데이터 프레임 형성
    output = pd.DataFrame()
    # 데이터의 컬럼 개수 설정
    k = x.shape[1]
    # VIF 측정
    vif = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
    for i in range(1,k):
        print(f'{i}번째 VIF 측정')
        # VIF 최대 값 선정
        a = np.argmax(vif)
        print(f'Max VIF feature & value : {x.columns[a]}, {vif[a]}')
        # VIF 최대 값이 임계치를 넘지 않는 경우 break
        if (vif[a] <= thresh):
            print('\n')
            for q in range(output.shape[1]):
                print(f'{output.columns[q]}의 vif는 {np.round(vif[q],2)}입니다.')
            break
        # VIF 최대 값이 임계치를 넘는 경우, + 1번째 시도인 경우 : if 문으로 해당 feature 제거 후 다시 vif 측정
        if (i == 1):
            output = x.drop(x.columns[a], axis = 1)
            vif = [variance_inflation_factor(output.values, j) for j in range(output.shape[1])]
        # VIF 최대 값이 임계치를 넘는 경우, + 1번째 이후 시도인 경우 : if 문으로 해당 feature 제거 후 다시 vif 측정
        elif (i > 1):
            output = output.drop(output.columns[a], axis = 1)
            vif = [variance_inflation_factor(output.values, j) for j in range(output.shape[1])]
    return(output)

# %%
df_corr = vif(df_corr)
# Out:
# 1번째 VIF 측정
# Max VIF feature & value : 소규모W, 902.8483250428363
# 2번째 VIF 측정
# Max VIF feature & value : 종합병원, 392.3402003312083
# 3번째 VIF 측정
# Max VIF feature & value : 유치원, 82.8568359526887
# 4번째 VIF 측정
# Max VIF feature & value : 중규모C, 55.231527303932474
# 5번째 VIF 측정
# Max VIF feature & value : 전규모W, 35.854263377768845
# 6번째 VIF 측정
# Max VIF feature & value : 전규모W, 26.753381363909426
# 7번째 VIF 측정
# Max VIF feature & value : 소규모W, 20.628649454375857
# 8번째 VIF 측정
# Max VIF feature & value : 약국, 18.530205109748756
# 9번째 VIF 측정
# Max VIF feature & value : 대규모C, 18.02538335976495
# 10번째 VIF 측정
# Max VIF feature & value : 소규모C, 9.601154426819297
#
#
# 1인당 자동차 등록대수의 vif는 9.54입니다.
# 고등학교의 vif는 7.38입니다.
# 대규모W의 vif는 4.51입니다.
# 병상 비율의 vif는 7.52입니다.
# 병원의 vif는 4.86입니다.
# 보건지소의 vif는 5.21입니다.
# 보육시설 비율의 vif는 4.2입니다.
# 소규모C의 vif는 5.66입니다.
# 요양병원의 vif는 9.6입니다.
# 전규모W의 vif는 7.57입니다.
# 종합병원의 vif는 3.46입니다.

# %%
df_corr
# Out:
#      1인당 자동차 등록대수      고등학교      대규모W     병상 비율    병원      보건지소   보육시설 비율  \
# 0        0.589518  0.308353  0.077085  0.834646  0.25  0.000000  0.253731
# 1        0.000000  0.286495  0.060698  0.417323  0.10  0.000000  0.559701
# 2        0.248847  0.352849  0.016423  0.509186  0.85  0.000000  0.111940
# 3        0.113627  0.719750  0.000000  0.598425  0.90  0.000000  0.000000
# 4        0.167715  0.366120  0.045013  0.301837  0.30  0.000000  0.432836
# ..            ...       ...       ...       ...   ...       ...       ...
# 110      0.575891  0.030445  0.155542  0.299213  0.00  0.705882  0.335821
# 111      0.717820  0.216237  0.440006  0.128609  0.00  0.529412  0.328358
# 112      0.511530  0.174083  0.521030  0.065617  0.05  0.588235  0.186567
# 113      0.571069  0.417642  0.772050  0.312336  0.15  0.647059  0.432836
# 114      0.598532  0.000000  1.000000  0.454068  0.05  0.941176  0.268657
#
#          소규모C      요양병원      전규모W  종합병원
# ...
